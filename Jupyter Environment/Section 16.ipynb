# %%
from PIL import Image

# %%
ibm = Image.open('my_computer_image.jpg')

# %%
ibm
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x331>

# %%
ibm.size
# Out:
# (220, 331)

# %%
ibm.filename
# Out:
# 'C:\\Users\\Admin\\My Python Stuff\\my_computer_image.jpg'

# %%
ibm.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
# Cropping image

# %%
ibm.crop((0,0,100,100))    # top left corner
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
ibm.size
# Out:
# (220, 331)

# %%
x = 0
y = 0

w = 220 / 3
h = 331 / 10

# %%
ibm.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=73x33>

# %%
x = 0
y = 180

w = 220 / 3
h = 331

# %%
ibm.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=73x151>

# %%
ibm.size
# Out:
# (220, 331)

# %%
halfway = 220 / 2

# %%
x = halfway - 50
w = halfway + 50

y = 180
h = 331

# %%
ibm.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=100x151>

# %%
computer = ibm.crop((x,y,w,h))

# %%
ibm.paste(im=computer,box=(0,0))

# %%
ibm
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x331>

# %%
ibm.size
# Out:
# (220, 331)

# %%
ibm.resize((300,200))
# Out:
# <PIL.Image.Image image mode=RGB size=300x200>

# %%
ibm.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=220x331>

# %%
# Color transparency RGBA - RED,GREEN,BLUE,ALPHA

# %%
ibm.putalpha(0)

# %%
ibm
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=220x331>

# %%
ibm.putalpha(255)

# %%
ibm
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=220x331>

# %%
ibm.putalpha(128)

# %%
ibm
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=220x331>

# %%
# ibm.save(---) overrides or creates
